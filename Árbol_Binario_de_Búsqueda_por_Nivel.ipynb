# %% [markdown]
# <a href="https://colab.research.google.com/github/Newball12/tuplas2/blob/main/%C3%81rbol_Binario_de_B%C3%BAsqueda_por_Nivel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# A. 15,6,18,3,7,17,20,2,4,13,9

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Definir la clase de nodo para el árbol binario de búsqueda
class Node:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

# Función para insertar valores en el árbol binario de búsqueda
def insert(raiz, value):
    if raiz is None:
        return Node(value)
    if value < raiz.value:
        raiz.left = insert(raiz.left, value)
    else:
        raiz.right = insert(raiz.right, value)
    return raiz

# Crear el árbol con los valores especificados
values = [15,6,18,3,7,17,20,2,4,13,9]
raiz = None
for value in values:
    raiz = insert(raiz, value)
# Definir los colores para cada nivel
color_map = {
    1: 'lightcoral',
    2: 'skyblue',
    3: 'plum',
    4: 'lightgreen',
    5: 'lightsalmon'
}
# Crear el gráfico del árbol binario de búsqueda
def add_edges(graph, node, level=1):
    if node is not None:
        graph.add_node(node.value, level=level)
        if node.left is not None:
            graph.add_edge(node.value, node.left.value)
            add_edges(graph, node.left, level+1)
        if node.right is not None:
            graph.add_edge(node.value, node.right.value)
            add_edges(graph, node.right, level+1)

# Crear el gráfico y agregar nodos y aristas
G = nx.DiGraph()
add_edges(G, raiz)
# Obtener los colores de los nodos basados en su nivel
node_colors = [color_map[data['level']] for _, data in G.nodes(data=True)]

# Definir posiciones específicas para cada nodo, imitando la disposición de la imagen
pos = {
    15: (0, 3),
    6: (-1, 2),
    18: (1, 2),
    3: (-1.5, 1),
    7: (-0.5, 1),
    17: (0.5, 1),
    20: (1.5, 1),
    2: (-2, 0),
    4: (-1, 0),
    13: (-0.3, 0),
    9: (-0.2,-1)
}

# Dibujar el gráfico
plt.figure(figsize=(10, 7))
nx.draw(G, pos, with_labels=True, node_size=1000, node_color=node_colors, font_size=15, font_weight="bold", arrows=True)
plt.title("Árbol Binario de Búsqueda por Nivel")
plt.show()

# %% [markdown]
# B. 25,15,50,10,22,35,70,4,12,18,24,31,44,66,90

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Definir la clase de nodo para el árbol binario de búsqueda
class Node:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

# Función para insertar valores en el árbol binario de búsqueda
def insert(raiz, value):
    if raiz is None:
        return Node(value)
    if value < raiz.value:
        raiz.left = insert(raiz.left, value)
    else:
        raiz.right = insert(raiz.right, value)
    return raiz

# Crear el árbol con los valores especificados
values = [25,15,50,10,22,35,70,4,12,18,24,31,44,66,90]
raiz = None
for value in values:
    raiz = insert(raiz, value)
    # Definir los colores para cada nivel
color_map = {
    1: 'lightcoral',
    2: 'skyblue',
    3: 'plum',
    4: 'lightgreen'
    }

# Crear el gráfico del árbol binario de búsqueda
def add_edges(graph, node, level=1):
    if node is not None:
        graph.add_node(node.value, level=level)
        if node.left is not None:
            graph.add_edge(node.value, node.left.value)
            add_edges(graph, node.left, level+1)
        if node.right is not None:
            graph.add_edge(node.value, node.right.value)
            add_edges(graph, node.right, level+1)

# Crear el gráfico y agregar nodos y aristas
G = nx.DiGraph()
add_edges(G, raiz)
# Obtener los colores de los nodos basados en su nivel
node_colors = [color_map[data['level']] for _, data in G.nodes(data=True)]

# Definir posiciones específicas para cada nodo, imitando la disposición de la imagen
pos = {
    25: (0, 3),
    15: (-1, 2),
    50: (1, 2),
    10: (-1.5, 1),
    22: (-0.5, 1),
    35: (0.5, 1),
    70: (1.5, 1),
    4: (-1.8, 0),
    12: (-1.2, 0),
    18: (-0.8, 0),
    24: (-0.2,0),
    31:(0.2,0),
    44:(0.8,0),
    66:(1.2,0),
    90:(1.8,0)
}

# Dibujar el gráfico
plt.figure(figsize=(10, 7))
nx.draw(G, pos, with_labels=True, node_size=1000, node_color=node_colors, font_size=15, font_weight="bold", arrows=True)
plt.title("Árbol Binario de Búsqueda por Nivel")
plt.show()

# %% [markdown]
# C. 30,20,40,10,25,35,50

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Definir la clase de nodo para el árbol binario de búsqueda
class Node:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

# Función para insertar valores en el árbol binario de búsqueda
def insert(raiz, value):
    if raiz is None:
        return Node(value)
    if value < raiz.value:
        raiz.left = insert(raiz.left, value)
    else:
        raiz.right = insert(raiz.right, value)
    return raiz

# Crear el árbol con los valores especificados
values = [30,20,40,10,25,35,50]
raiz = None
for value in values:
    raiz = insert(raiz, value)

    # Definir los colores para cada nivel
color_map = {
    1: 'lightcoral',
    2: 'skyblue',
    3: 'plum'
    }

# Crear el gráfico del árbol binario de búsqueda
def add_edges(graph, node, level=1):
    if node is not None:
        graph.add_node(node.value, level=level)
        if node.left is not None:
            graph.add_edge(node.value, node.left.value)
            add_edges(graph, node.left, level+1)
        if node.right is not None:
            graph.add_edge(node.value, node.right.value)
            add_edges(graph, node.right, level+1)

# Crear el gráfico y agregar nodos y aristas
G = nx.DiGraph()
add_edges(G, raiz)
# Obtener los colores de los nodos basados en su nivel
node_colors = [color_map[data['level']] for _, data in G.nodes(data=True)]

# Definir posiciones específicas para cada nodo, imitando la disposición de la imagen
pos = {
    30: (0, 3),
    20: (-1, 2),
    40: (1, 2),
    10: (-1.5, 1),
    25: (-0.5, 1),
    35: (0.5, 1),
    50: (1.5, 1)
}

# Dibujar el gráfico
plt.figure(figsize=(10, 7))
nx.draw(G, pos, with_labels=True, node_size=1000, node_color=node_colors, font_size=15, font_weight="bold", arrows=True)
plt.title("Árbol Binario de Búsqueda por Nivel")
plt.show()

# %% [markdown]
# D. 27,14,35,10,19,31,42,9,12,18,20,30,33,38,45

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Definir la clase de nodo para el árbol binario de búsqueda
class Node:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

# Función para insertar valores en el árbol binario de búsqueda
def insert(raiz, value):
    if raiz is None:
        return Node(value)
    if value < raiz.value:
        raiz.left = insert(raiz.left, value)
    else:
        raiz.right = insert(raiz.right, value)
    return raiz

# Crear el árbol con los valores especificados
values = [27,14,35,10,19,31,42,9,12,18,20,30,33,38,45]
raiz = None
for value in values:
    raiz = insert(raiz, value)

    # Definir los colores para cada nivel
color_map = {
    1: 'lightcoral',
    2: 'skyblue',
    3: 'plum',
    4: 'lightgreen'
    }

# Crear el gráfico del árbol binario de búsqueda
def add_edges(graph, node, level=1):
    if node is not None:
        graph.add_node(node.value, level=level)
        if node.left is not None:
            graph.add_edge(node.value, node.left.value)
            add_edges(graph, node.left, level+1)
        if node.right is not None:
            graph.add_edge(node.value, node.right.value)
            add_edges(graph, node.right, level+1)

# Crear el gráfico y agregar nodos y aristas
G = nx.DiGraph()
add_edges(G, raiz)
# Obtener los colores de los nodos basados en su nivel
node_colors = [color_map[data['level']] for _, data in G.nodes(data=True)]

# Definir posiciones específicas para cada nodo, imitando la disposición de la imagen
pos = {
    27: (0, 3),
    14: (-1, 2),
    35: (1, 2),
    10: (-1.5, 1),
    19: (-0.5, 1),
    31: (0.5, 1),
    42: (1.5, 1),
    9: (-1.8, 0),
    12: (-1.2, 0),
    18: (-0.8, 0),
    20: (-0.2,0),
    30:(0.2,0),
    33:(0.8,0),
    38:(1.2,0),
    45:(1.8,0)
}

# Dibujar el gráfico
plt.figure(figsize=(10, 7))
nx.draw(G, pos, with_labels=True, node_size=1000, node_color=node_colors, font_size=15, font_weight="bold", arrows=True)
plt.title("Árbol Binario de Búsqueda por Nivel")
plt.show()
